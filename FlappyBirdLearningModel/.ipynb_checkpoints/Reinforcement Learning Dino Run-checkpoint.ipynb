# %%
import numpy as np
from PIL import Image
import cv2 #opencv
import io
import time
import pandas as pd
import numpy as np
from IPython.display import clear_output
from random import randint
import os

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

#keras imports
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD , Adam
from keras.callbacks import TensorBoard
from collections import deque
import random
import pickle
from io import BytesIO
import base64
import json
import tensorflow as tf
 
print("VERSION", tf.Session(config=tf.ConfigProto(log_device_placement=True)))

from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# VERSION <tensorflow.python.client.session.Session object at 0x0000016AEE7E5048>
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10172444926724377672
# ]

# %%
#path variables
game_url = "http://flappybird.io/"
chrome_driver_path = "./chromedriver"
loss_file_path = "./objects/loss_df.csv"
actions_file_path = "./objects/actions_df.csv"
q_value_file_path = "./objects/q_values.csv"
scores_file_path = "./objects/scores_df.csv"

#scripts
#create id for canvas for faster selection from DOM
init_script = "document.getElementsByClassName('canvas-container')[0].id = 'canvas-container'"

#get image from canvas
# getbase64Script = "canvasContainer = document.getElementById('canvas-container'); \
# return canvasContainer.toDataURL().substring(22)"
getbase64Script = "return document.getElementById('testCanvas').toDataURL().substring(22)"

alive_t0 = 0
alive_tf = 0

# %%
'''
* Game class: Selenium interfacing between the python and browser
* __init__():  Launch the broswer window using the attributes in chrome_options
* get_crashed() : return true if the agent as crashed on an obstacles. Gets javascript variable from game decribing the state
* get_playing(): true if game in progress, false is crashed or paused
* restart() : sends a signal to browser-javascript to restart the game
* press_up(): sends a single to press up get to the browser
* get_score(): gets current game score from javascript variables.
* pause(): pause the game
* resume(): resume a paused game if not crashed
* end(): close the browser and end the game
'''
class Game:
    def __init__(self,custom_config=True):
        chrome_options = Options()
        chrome_options.add_argument("disable-infobars")
        chrome_options.add_argument("--mute-audio")
        self._driver = webdriver.Chrome(executable_path = chrome_driver_path,chrome_options=chrome_options)
        self._driver.set_window_position(x=-10,y=0)
        self._driver.get(game_url)
        # self._driver.execute_script("Runner.config.ACCELERATION=0")
        self._driver.execute_script(init_script)
    def get_crashed(self):
        return self._driver.execute_script("return dead")
    def get_playing(self):
        return self._driver.execute_script("return started")
    def restart(self):
        global alive_t0
        self._driver.execute_script("spacebar();")
        alive_t0 = int(round(time.time() * 1000))
    def press_up(self):
        self._driver.execute_script("spacebar();")
    def get_score(self):
        global alive_t0
        global alive_tf
        alive_tf = int(round(time.time() * 1000))
        score = alive_tf - alive_t0
#         score = ''.join(score_array) # the javascript object is of type array with score in the formate[1,0,0] which is 100.
        return score
    def pause(self):
        return self._driver.execute_script("spacebar();")
    def resume(self):
        return self._driver.execute_script("spacebar();")
    def end(self):
        self._driver.close()

# %%
class DinoAgent:
    def __init__(self,game): #takes game as input for taking actions
        self._game = game; 
        self.jump(); #to start the game, we need to jump once
    def is_running(self):
        return self._game.get_playing()
    def is_crashed(self):
        return self._game.get_crashed()
    def jump(self):
        self._game.press_up()
    def duck(self):
        self._game.press_down()

# %%
class Game_sate:
    def __init__(self,agent,game):
        self._agent = agent
        self._game = game
        self._display = show_img() #display the processed image on screen using openCV, implemented using python coroutine 
        self._display.__next__() # initiliaze the display coroutine 
    def get_state(self,actions):
        actions_df.loc[len(actions_df)] = actions[1] # storing actions in a dataframe
        score = self._game.get_score() 
        reward = 0.1
        is_over = False #game over
        if actions[1] == 1:
            self._agent.jump()
        image = grab_screen(self._game._driver) 
        self._display.send(image) #display the image on screen
        if self._agent.is_crashed():
            scores_df.loc[len(loss_df)] = score # log the score when game is over
            self._game.restart()
            reward = -1
            is_over = True
        return image, reward, is_over #return the Experience tuple

# %%
def save_obj(obj, name ):
    with open('objects/'+ name + '.pkl', 'wb') as f: #dump files into objects folder
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name ):
    with open('objects/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def grab_screen(_driver):
    image_b64 = _driver.execute_script(getbase64Script)
    screen = np.array(Image.open(BytesIO(base64.b64decode(image_b64))))
    image = process_img(screen)#processing image as required
    return image

def process_img(image):
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #RGB to Grey Scale
    image = image[:1200, :1000] #Crop Region of Interest(ROI)
    image = cv2.resize(image, (80,80))
    return  image

def show_img(graphs = False):
    """
    Show images in new window
    """
    while True:
        screen = (yield)
        window_title = "logs" if graphs else "game_play"
        cv2.namedWindow(window_title, cv2.WINDOW_NORMAL)        
        imS = cv2.resize(screen, (800, 400)) 
        cv2.imshow(window_title, screen)
        if (cv2.waitKey(1) & 0xFF == ord('q')):
            cv2.destroyAllWindows()
            break

# %%
#Intialize log structures from file if exists else create new
loss_df = pd.read_csv(loss_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns =['loss'])
scores_df = pd.read_csv(scores_file_path) if os.path.isfile(loss_file_path) else pd.DataFrame(columns = ['scores'])
actions_df = pd.read_csv(actions_file_path) if os.path.isfile(actions_file_path) else pd.DataFrame(columns = ['actions'])
q_values_df =pd.read_csv(actions_file_path) if os.path.isfile(q_value_file_path) else pd.DataFrame(columns = ['qvalues'])

# %%
#game parameters
ACTIONS = 2 # possible actions: jump, do nothing
GAMMA = 0.99 # decay rate of past observations original 0.99
OBSERVATION = 100. # timesteps to observe before training
EXPLORE = 100000  # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 16 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4
img_rows , img_cols = 80,80
img_channels = 4 #We stack 4 frames

# %%
# training variables saved as checkpoints to filesystem to resume training from the same step
def init_cache():
    """initial variable caching, done only once"""
    save_obj(INITIAL_EPSILON,"epsilon")
    t = 0
    save_obj(t,"time")
    D = deque()
    save_obj(D,"D")

# %%
'''Call only once to init file structure
'''
#init_cache()
# Out:
# 'Call only once to init file structure\n'

# %%
def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Conv2D(32, (8, 8), padding='same',strides=(4, 4),input_shape=(img_cols,img_rows,img_channels)))  #80*80*4
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (4, 4),strides=(2, 2),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3),strides=(1, 1),  padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(ACTIONS))
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    
    #create model file if not present
    if not os.path.isfile(loss_file_path):
        model.save_weights('model.h5')
    print("We finish building the model")
    return model

# %%
''' 
main training module
Parameters:
* model => Keras Model to be trained
* game_state => Game State module with access to game environment and dino
* observe => flag to indicate wherther the model is to be trained(weight updates), else just play
'''
def trainNetwork(model,game_state,observe=False):
    last_time = time.time()
    # store the previous observations in replay memory
    D = load_obj("D") #load from file system
    # get the first state by doing nothing
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] =1 #0 => do nothing,
                     #1=> jump
    
    x_t, r_0, terminal = game_state.get_state(do_nothing) # get next step after performing the action
    

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2) # stack 4 images to create placeholder input
    

    
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*20*40*4
    
    initial_state = s_t 

    if observe :
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = load_obj("epsilon") 
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)

    t = load_obj("time") # resume from the previous time step stored in file system
    while (True): #endless running
        
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0 #reward at 4
        a_t = np.zeros([ACTIONS]) # action at t
        
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0: #parameter to skip frames for actions
            if  random.random() <= epsilon: #randomly explore an action
                print("----------Random Action----------")
                action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else: # predict the output
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)         # chosing index with maximum q value
                action_index = max_Q 
                a_t[action_index] = 1        # o=> do nothing, 1=> jump
                
        #We reduced the epsilon (exploration parameter) gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE 

        #run the selected action and observed next state and reward
        x_t1, r_t, terminal = game_state.get_state(a_t)
        print('fps: {0}'.format(1 / (time.time()-last_time))) # helpful for measuring frame rate
        last_time = time.time()
        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x20x40x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3) # append the new image to input stack and remove the first one
        
        
        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE: 
            
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)
            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 20, 40, 4
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]    # 4D stack of images
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]   #reward at state_t due to action_t
                state_t1 = minibatch[i][3]   #next state
                terminal = minibatch[i][4]   #wheather the agent died or survided due the action
                

                inputs[i:i + 1] = state_t    

                targets[i] = model.predict(state_t)  # predicted q values
                Q_sa = model.predict(state_t1)      #predict q values for next step
                
                if terminal:
                    targets[i, action_t] = reward_t # if terminated, only equals reward
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            loss += model.train_on_batch(inputs, targets)
            loss_df.loc[len(loss_df)] = loss
            q_values_df.loc[len(q_values_df)] = np.max(Q_sa)
        s_t = initial_state if terminal else s_t1 #reset game to initial frame if terminate
        t = t + 1
        
        # save progress every 1000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            game_state._game.pause() #pause game while saving to filesystem
            model.save_weights("model.h5", overwrite=True)
            save_obj(D,"D") #saving episodes
            save_obj(t,"time") #caching time steps
            save_obj(epsilon,"epsilon") #cache epsilon to avoid repeated randomness in actions
            loss_df.to_csv("./objects/loss_df.csv",index=False)
            scores_df.to_csv("./objects/scores_df.csv",index=False)
            actions_df.to_csv("./objects/actions_df.csv",index=False)
            q_values_df.to_csv(q_value_file_path,index=False)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)
            clear_output()
            game_state._game.resume()
        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state,             "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t,             "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
#main function
def playGame(observe=False):
    game = Game()
    time.sleep(3)
    dino = DinoAgent(game)
    game_state = Game_sate(dino,game)    
    model = buildmodel()
    try:
        trainNetwork(model,game_state,observe=observe)
    except StopIteration:
        game.end()

# %%
playGame(observe=False);
# Out:
# TIMESTEP 49000 / STATE explore / EPSILON 0.051149898999925364 / ACTION 1 / REWARD 0.1 / Q_MAX  1.0866374 / Loss  0.22778764367103577
# fps: 0.05171366848545687
# TIMESTEP 49001 / STATE explore / EPSILON 0.05114889999992536 / ACTION 1 / REWARD 0.1 / Q_MAX  6.445688 / Loss  0.3547983467578888
# fps: 4.7081411037848735
# TIMESTEP 49002 / STATE explore / EPSILON 0.05114790099992536 / ACTION 1 / REWARD 0.1 / Q_MAX  6.1246924 / Loss  0.3773643374443054
# fps: 4.564900915961411
# TIMESTEP 49003 / STATE explore / EPSILON 0.05114690199992536 / ACTION 1 / REWARD 0.1 / Q_MAX  3.1428912 / Loss  0.28643798828125
# fps: 6.779768851531561
# TIMESTEP 49004 / STATE explore / EPSILON 0.05114590299992536 / ACTION 1 / REWARD 0.1 / Q_MAX  4.5327854 / Loss  0.21186813712120056
# fps: 6.9746045682510545
# TIMESTEP 49005 / STATE explore / EPSILON 0.051144903999925356 / ACTION 1 / REWARD 0.1 / Q_MAX  5.4404106 / Loss  0.19041967391967773
# fps: 7.036383889627035
# TIMESTEP 49006 / STATE explore / EPSILON 0.051143904999925355 / ACTION 1 / REWARD 0.1 / Q_MAX  7.5262785 / Loss  0.18083126842975616
# fps: 7.896602297266512
# TIMESTEP 49007 / STATE explore / EPSILON 0.05114290599992535 / ACTION 1 / REWARD 0.1 / Q_MAX  6.2633157 / Loss  0.16232994198799133
# fps: 5.622157792370558
# TIMESTEP 49008 / STATE explore / EPSILON 0.05114190699992535 / ACTION 1 / REWARD 0.1 / Q_MAX  5.8156767 / Loss  0.10883235186338425
# fps: 3.4510312438033632
# TIMESTEP 49009 / STATE explore / EPSILON 0.05114090799992535 / ACTION 1 / REWARD 0.1 / Q_MAX  5.149553 / Loss  0.18173837661743164
# fps: 4.9464923608531315
# TIMESTEP 49010 / STATE explore / EPSILON 0.05113990899992535 / ACTION 1 / REWARD 0.1 / Q_MAX  6.1109004 / Loss  0.168770432472229
# fps: 6.060712551730516
# TIMESTEP 49011 / STATE explore / EPSILON 0.05113890999992535 / ACTION 1 / REWARD 0.1 / Q_MAX  7.2638264 / Loss  0.2262059897184372
# fps: 4.039856255496128
# TIMESTEP 49012 / STATE explore / EPSILON 0.051137910999925346 / ACTION 1 / REWARD 0.1 / Q_MAX  3.923281 / Loss  0.5285319089889526
# fps: 5.791797619376398
# TIMESTEP 49013 / STATE explore / EPSILON 0.051136911999925344 / ACTION 1 / REWARD 0.1 / Q_MAX  7.2176566 / Loss  0.11478772759437561
# fps: 6.559472777971528
# TIMESTEP 49014 / STATE explore / EPSILON 0.05113591299992534 / ACTION 1 / REWARD 0.1 / Q_MAX  4.7587 / Loss  0.32392460107803345
# fps: 5.663623511111051
# TIMESTEP 49015 / STATE explore / EPSILON 0.05113491399992534 / ACTION 1 / REWARD 0.1 / Q_MAX  2.1075025 / Loss  0.42301249504089355
# fps: 3.3296847587066454
# TIMESTEP 49016 / STATE explore / EPSILON 0.05113391499992534 / ACTION 1 / REWARD 0.1 / Q_MAX  1.3032161 / Loss  0.391785204410553
# fps: 4.357397012791783
# TIMESTEP 49017 / STATE explore / EPSILON 0.05113291599992534 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4177182 / Loss  0.2972872853279114
# fps: 4.26265135177435
# TIMESTEP 49018 / STATE explore / EPSILON 0.051131916999925336 / ACTION 1 / REWARD 0.1 / Q_MAX  5.7522974 / Loss  0.23946556448936462
# fps: 2.63987457413551
# TIMESTEP 49019 / STATE explore / EPSILON 0.051130917999925335 / ACTION 1 / REWARD 0.1 / Q_MAX  6.552736 / Loss  0.2819204032421112
# fps: 3.640832000888875
# TIMESTEP 49020 / STATE explore / EPSILON 0.05112991899992533 / ACTION 1 / REWARD 0.1 / Q_MAX  3.7966924 / Loss  0.13411855697631836
# fps: 7.3453996507948185
# TIMESTEP 49021 / STATE explore / EPSILON 0.05112891999992533 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.44256735 / Loss  0.48786473274230957
# fps: 4.025104698877966
# TIMESTEP 49022 / STATE explore / EPSILON 0.05112792099992533 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7728868 / Loss  0.26587897539138794
# fps: 2.329008266436115
# TIMESTEP 49023 / STATE explore / EPSILON 0.05112692199992533 / ACTION 1 / REWARD -1 / Q_MAX  6.5627246 / Loss  0.1420268416404724
# fps: 4.1593323337379315
# TIMESTEP 49024 / STATE explore / EPSILON 0.05112592299992533 / ACTION 1 / REWARD -1 / Q_MAX  3.351095 / Loss  0.33979669213294983
# fps: 4.420668764768749
# TIMESTEP 49025 / STATE explore / EPSILON 0.051124923999925326 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4951934 / Loss  0.5816739797592163
# fps: 5.440224130327635
# TIMESTEP 49026 / STATE explore / EPSILON 0.051123924999925324 / ACTION 1 / REWARD 0.1 / Q_MAX  7.4387727 / Loss  0.22056543827056885
# ----------Random Action----------
# fps: 5.551281440422682
# TIMESTEP 49027 / STATE explore / EPSILON 0.05112292599992532 / ACTION 0 / REWARD 0.1 / Q_MAX  7.478179 / Loss  0.13808368146419525
# fps: 5.838063250844537
# TIMESTEP 49028 / STATE explore / EPSILON 0.05112192699992532 / ACTION 0 / REWARD 0.1 / Q_MAX  6.8828516 / Loss  0.1402004063129425
# fps: 6.01319251000334
# TIMESTEP 49029 / STATE explore / EPSILON 0.05112092799992532 / ACTION 1 / REWARD 0.1 / Q_MAX  7.927426 / Loss  0.13613899052143097
# fps: 7.6791610291600225
# TIMESTEP 49030 / STATE explore / EPSILON 0.05111992899992532 / ACTION 1 / REWARD 0.1 / Q_MAX  7.387957 / Loss  0.3693985342979431
# fps: 4.517883879195758
# TIMESTEP 49031 / STATE explore / EPSILON 0.05111892999992532 / ACTION 1 / REWARD 0.1 / Q_MAX  7.3528395 / Loss  0.05592241883277893
# fps: 6.6514490512777815
# TIMESTEP 49032 / STATE explore / EPSILON 0.051117930999925315 / ACTION 1 / REWARD 0.1 / Q_MAX  7.274676 / Loss  0.5021417140960693
# fps: 4.254824625472724
# TIMESTEP 49033 / STATE explore / EPSILON 0.051116931999925314 / ACTION 1 / REWARD 0.1 / Q_MAX  7.483204 / Loss  0.25104835629463196
# fps: 7.141623418195687
# TIMESTEP 49034 / STATE explore / EPSILON 0.05111593299992531 / ACTION 1 / REWARD 0.1 / Q_MAX  9.417308 / Loss  0.1276504397392273
# ----------Random Action----------
# fps: 7.333609591400331
# TIMESTEP 49035 / STATE explore / EPSILON 0.05111493399992531 / ACTION 0 / REWARD 0.1 / Q_MAX  6.367173 / Loss  0.32111239433288574
# fps: 7.368705475180295
# TIMESTEP 49036 / STATE explore / EPSILON 0.05111393499992531 / ACTION 1 / REWARD 0.1 / Q_MAX  3.867431 / Loss  0.10157284140586853
# ----------Random Action----------
# fps: 3.9371417146257874
# TIMESTEP 49037 / STATE explore / EPSILON 0.05111293599992531 / ACTION 0 / REWARD 0.1 / Q_MAX  2.230243 / Loss  0.12160763144493103
# fps: 8.120564409956167
# TIMESTEP 49038 / STATE explore / EPSILON 0.051111936999925306 / ACTION 1 / REWARD 0.1 / Q_MAX  7.559468 / Loss  0.21270740032196045
# fps: 7.252365406960659
# TIMESTEP 49039 / STATE explore / EPSILON 0.051110937999925304 / ACTION 1 / REWARD 0.1 / Q_MAX  5.635684 / Loss  0.23480023443698883
# fps: 6.6435158346242424
# TIMESTEP 49040 / STATE explore / EPSILON 0.0511099389999253 / ACTION 1 / REWARD 0.1 / Q_MAX  5.5249114 / Loss  0.5945827960968018
# fps: 4.802640001007634
# TIMESTEP 49041 / STATE explore / EPSILON 0.0511089399999253 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9945228 / Loss  0.40226608514785767
# fps: 4.364179694612804
# TIMESTEP 49042 / STATE explore / EPSILON 0.0511079409999253 / ACTION 1 / REWARD 0.1 / Q_MAX  8.127834 / Loss  0.11335481703281403
# fps: 6.090060736475135
# TIMESTEP 49043 / STATE explore / EPSILON 0.0511069419999253 / ACTION 1 / REWARD 0.1 / Q_MAX  2.1287267 / Loss  0.13491427898406982
# fps: 6.867599527129473
# TIMESTEP 49044 / STATE explore / EPSILON 0.0511059429999253 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6438848 / Loss  0.21637099981307983
# fps: 6.812772779471553
# TIMESTEP 49045 / STATE explore / EPSILON 0.051104943999925295 / ACTION 1 / REWARD 0.1 / Q_MAX  7.516617 / Loss  0.316739559173584
# fps: 4.961952837655109
# TIMESTEP 49046 / STATE explore / EPSILON 0.051103944999925294 / ACTION 1 / REWARD 0.1 / Q_MAX  2.1604066 / Loss  0.19039689004421234
# ----------Random Action----------
# fps: 5.334676444926065
# TIMESTEP 49047 / STATE explore / EPSILON 0.05110294599992529 / ACTION 0 / REWARD 0.1 / Q_MAX  4.142816 / Loss  0.12797605991363525
# fps: 4.610761841840565
# TIMESTEP 49048 / STATE explore / EPSILON 0.05110194699992529 / ACTION 1 / REWARD 0.1 / Q_MAX  5.4135904 / Loss  0.2068694829940796
# fps: 6.050666693595039
# TIMESTEP 49049 / STATE explore / EPSILON 0.05110094799992529 / ACTION 1 / REWARD 0.1 / Q_MAX  9.080394 / Loss  0.3709060251712799
# fps: 6.973862381782147
# TIMESTEP 49050 / STATE explore / EPSILON 0.05109994899992529 / ACTION 1 / REWARD 0.1 / Q_MAX  1.313237 / Loss  0.3428875803947449
# fps: 7.0149655130889705
# TIMESTEP 49051 / STATE explore / EPSILON 0.051098949999925286 / ACTION 1 / REWARD 0.1 / Q_MAX  8.059371 / Loss  0.39969155192375183
# fps: 4.679492500412801
# TIMESTEP 49052 / STATE explore / EPSILON 0.051097950999925285 / ACTION 1 / REWARD 0.1 / Q_MAX  6.686906 / Loss  0.410326212644577
# fps: 5.90644719295108
# TIMESTEP 49053 / STATE explore / EPSILON 0.05109695199992528 / ACTION 1 / REWARD 0.1 / Q_MAX  2.4037168 / Loss  0.5906851291656494
# fps: 5.853756027438365
# TIMESTEP 49054 / STATE explore / EPSILON 0.05109595299992528 / ACTION 1 / REWARD -1 / Q_MAX  3.7440362 / Loss  0.1627730280160904
# fps: 6.011296520035486
# TIMESTEP 49055 / STATE explore / EPSILON 0.05109495399992528 / ACTION 0 / REWARD -1 / Q_MAX  8.882704 / Loss  0.17233194410800934
# fps: 3.612201362615823
# TIMESTEP 49056 / STATE explore / EPSILON 0.05109395499992528 / ACTION 0 / REWARD -1 / Q_MAX  4.650679 / Loss  0.4352046251296997
# fps: 4.71195462291929
# TIMESTEP 49057 / STATE explore / EPSILON 0.05109295599992528 / ACTION 0 / REWARD 0.1 / Q_MAX  6.963593 / Loss  0.465013325214386
# fps: 4.148504510207311
# TIMESTEP 49058 / STATE explore / EPSILON 0.051091956999925275 / ACTION 1 / REWARD 0.1 / Q_MAX  5.1642423 / Loss  0.4442693591117859
# fps: 5.608430488716426
# TIMESTEP 49059 / STATE explore / EPSILON 0.051090957999925274 / ACTION 1 / REWARD 0.1 / Q_MAX  3.9511566 / Loss  0.358495831489563
# fps: 6.067261583593832
# TIMESTEP 49060 / STATE explore / EPSILON 0.05108995899992527 / ACTION 1 / REWARD 0.1 / Q_MAX  6.2552977 / Loss  0.1393037587404251
# fps: 5.837364497089184
# TIMESTEP 49061 / STATE explore / EPSILON 0.05108895999992527 / ACTION 1 / REWARD 0.1 / Q_MAX  8.298418 / Loss  0.4415566027164459
# fps: 5.352731430788354
# TIMESTEP 49062 / STATE explore / EPSILON 0.05108796099992527 / ACTION 1 / REWARD 0.1 / Q_MAX  2.1524067 / Loss  0.24294832348823547
# fps: 3.0510641579047677
# TIMESTEP 49063 / STATE explore / EPSILON 0.05108696199992527 / ACTION 1 / REWARD 0.1 / Q_MAX  6.566907 / Loss  0.19427770376205444
# fps: 5.117832168258807
# TIMESTEP 49064 / STATE explore / EPSILON 0.051085962999925266 / ACTION 1 / REWARD 0.1 / Q_MAX  6.282617 / Loss  0.37428468465805054
# fps: 7.211218012640208
# TIMESTEP 49065 / STATE explore / EPSILON 0.051084963999925265 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0865433 / Loss  0.23265619575977325
# fps: 6.305014934616894
# TIMESTEP 49066 / STATE explore / EPSILON 0.05108396499992526 / ACTION 1 / REWARD 0.1 / Q_MAX  7.1417646 / Loss  0.26867038011550903
# fps: 6.5559765414962925
# TIMESTEP 49067 / STATE explore / EPSILON 0.05108296599992526 / ACTION 1 / REWARD 0.1 / Q_MAX  1.265958 / Loss  0.730552077293396
# fps: 7.285053522330354
# TIMESTEP 49068 / STATE explore / EPSILON 0.05108196699992526 / ACTION 1 / REWARD 0.1 / Q_MAX  4.131717 / Loss  0.3560883402824402
# fps: 6.317122468589881
# TIMESTEP 49069 / STATE explore / EPSILON 0.05108096799992526 / ACTION 1 / REWARD 0.1 / Q_MAX  4.000759 / Loss  0.12768949568271637
# fps: 6.4962804752442125
# TIMESTEP 49070 / STATE explore / EPSILON 0.05107996899992526 / ACTION 1 / REWARD 0.1 / Q_MAX  6.0689106 / Loss  0.10811613500118256
# fps: 7.284370305403833
# TIMESTEP 49071 / STATE explore / EPSILON 0.051078969999925256 / ACTION 1 / REWARD 0.1 / Q_MAX  6.8146396 / Loss  0.1975311040878296
# fps: 7.008506848422365
# TIMESTEP 49072 / STATE explore / EPSILON 0.051077970999925254 / ACTION 1 / REWARD 0.1 / Q_MAX  5.818979 / Loss  0.11013846099376678
# fps: 5.768530094168486
# TIMESTEP 49073 / STATE explore / EPSILON 0.05107697199992525 / ACTION 1 / REWARD 0.1 / Q_MAX  7.8116345 / Loss  0.21419674158096313
# fps: 6.634090172166995
# TIMESTEP 49074 / STATE explore / EPSILON 0.05107597299992525 / ACTION 1 / REWARD 0.1 / Q_MAX  3.6374795 / Loss  0.1984531283378601
# fps: 4.218976575010663
# TIMESTEP 49075 / STATE explore / EPSILON 0.05107497399992525 / ACTION 1 / REWARD 0.1 / Q_MAX  6.8054657 / Loss  0.13396261632442474
# fps: 3.8987803483736276
# TIMESTEP 49076 / STATE explore / EPSILON 0.05107397499992525 / ACTION 1 / REWARD 0.1 / Q_MAX  6.121885 / Loss  0.3023914098739624
# fps: 6.0345703737594345
# TIMESTEP 49077 / STATE explore / EPSILON 0.051072975999925246 / ACTION 1 / REWARD 0.1 / Q_MAX  7.0550966 / Loss  0.13257992267608643
# fps: 3.3789362680847397
# TIMESTEP 49078 / STATE explore / EPSILON 0.051071976999925245 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5933111 / Loss  0.07536205649375916
# fps: 3.3647460498787045
# TIMESTEP 49079 / STATE explore / EPSILON 0.05107097799992524 / ACTION 1 / REWARD 0.1 / Q_MAX  2.229223 / Loss  0.12919768691062927
# fps: 3.6311302264054244
# TIMESTEP 49080 / STATE explore / EPSILON 0.05106997899992524 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8840528 / Loss  0.16448922455310822
# fps: 5.542090540678031
# TIMESTEP 49081 / STATE explore / EPSILON 0.05106897999992524 / ACTION 1 / REWARD 0.1 / Q_MAX  2.8077586 / Loss  0.3224654793739319
# fps: 4.058749871782218
# TIMESTEP 49082 / STATE explore / EPSILON 0.05106798099992524 / ACTION 1 / REWARD 0.1 / Q_MAX  7.5514727 / Loss  0.21505719423294067
# ----------Random Action----------
# fps: 4.113119252200075
# TIMESTEP 49083 / STATE explore / EPSILON 0.05106698199992524 / ACTION 1 / REWARD -1 / Q_MAX  6.779976 / Loss  0.37442654371261597
# fps: 2.2966002485886845
# TIMESTEP 49084 / STATE explore / EPSILON 0.051065982999925236 / ACTION 0 / REWARD -1 / Q_MAX  8.892422 / Loss  0.17261162400245667
# ----------Random Action----------
# fps: 4.739080228598287
# TIMESTEP 49085 / STATE explore / EPSILON 0.051064983999925234 / ACTION 0 / REWARD 0.1 / Q_MAX  3.9068215 / Loss  0.2650594413280487
# fps: 2.6551033921330065
# TIMESTEP 49086 / STATE explore / EPSILON 0.05106398499992523 / ACTION 0 / REWARD 0.1 / Q_MAX  6.798936 / Loss  0.28745079040527344
# fps: 5.21162976502149
# TIMESTEP 49087 / STATE explore / EPSILON 0.05106298599992523 / ACTION 0 / REWARD 0.1 / Q_MAX  7.436801 / Loss  0.5690528154373169
# fps: 6.138377150617891
# TIMESTEP 49088 / STATE explore / EPSILON 0.05106198699992523 / ACTION 1 / REWARD 0.1 / Q_MAX  4.290968 / Loss  0.10701456665992737
# fps: 4.438872561522188
# TIMESTEP 49089 / STATE explore / EPSILON 0.05106098799992523 / ACTION 0 / REWARD 0.1 / Q_MAX  6.563167 / Loss  0.4414369463920593
# fps: 4.545700267801889
# TIMESTEP 49090 / STATE explore / EPSILON 0.05105998899992523 / ACTION 0 / REWARD 0.1 / Q_MAX  5.8581696 / Loss  0.3139318525791168
# fps: 4.226424828698105
# TIMESTEP 49091 / STATE explore / EPSILON 0.051058989999925225 / ACTION 1 / REWARD 0.1 / Q_MAX  1.7683873 / Loss  0.08841738849878311
# fps: 3.8480594580262557
# TIMESTEP 49092 / STATE explore / EPSILON 0.051057990999925223 / ACTION 1 / REWARD 0.1 / Q_MAX  8.086766 / Loss  0.13428378105163574
# fps: 2.6077120260031097
# TIMESTEP 49093 / STATE explore / EPSILON 0.05105699199992522 / ACTION 1 / REWARD 0.1 / Q_MAX  8.2622 / Loss  1.0811737775802612
# fps: 4.21458458100379
# TIMESTEP 49094 / STATE explore / EPSILON 0.05105599299992522 / ACTION 0 / REWARD 0.1 / Q_MAX  6.471421 / Loss  0.16635873913764954
# fps: 4.186132669030053
# TIMESTEP 49095 / STATE explore / EPSILON 0.05105499399992522 / ACTION 1 / REWARD 0.1 / Q_MAX  8.243577 / Loss  0.3769291043281555
# fps: 3.47434069761759
# TIMESTEP 49096 / STATE explore / EPSILON 0.05105399499992522 / ACTION 1 / REWARD 0.1 / Q_MAX  6.70247 / Loss  0.34220051765441895
# fps: 5.940359936493459
# TIMESTEP 49097 / STATE explore / EPSILON 0.051052995999925216 / ACTION 1 / REWARD 0.1 / Q_MAX  0.8036221 / Loss  0.4232027530670166
# fps: 7.569470211583301
# TIMESTEP 49098 / STATE explore / EPSILON 0.051051996999925214 / ACTION 1 / REWARD 0.1 / Q_MAX  0.17076498 / Loss  0.29462212324142456
# fps: 6.593138225797832
# TIMESTEP 49099 / STATE explore / EPSILON 0.05105099799992521 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0714157 / Loss  0.3344850540161133
# fps: 4.643158092834291
# TIMESTEP 49100 / STATE explore / EPSILON 0.05104999899992521 / ACTION 1 / REWARD 0.1 / Q_MAX  5.3705225 / Loss  0.15889176726341248
# fps: 4.548899840355383
# TIMESTEP 49101 / STATE explore / EPSILON 0.05104899999992521 / ACTION 1 / REWARD 0.1 / Q_MAX  7.4437056 / Loss  0.3561455309391022
# fps: 3.7283994734039667
# TIMESTEP 49102 / STATE explore / EPSILON 0.05104800099992521 / ACTION 1 / REWARD 0.1 / Q_MAX  5.98536 / Loss  0.1251632124185562
# fps: 4.579504436141616
# TIMESTEP 49103 / STATE explore / EPSILON 0.05104700199992521 / ACTION 1 / REWARD 0.1 / Q_MAX  4.173239 / Loss  0.4099239706993103
# fps: 4.714555162142416
# TIMESTEP 49104 / STATE explore / EPSILON 0.051046002999925205 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9363747 / Loss  0.08285687118768692
# fps: 4.849483811367134
# TIMESTEP 49105 / STATE explore / EPSILON 0.051045003999925204 / ACTION 1 / REWARD 0.1 / Q_MAX  6.564798 / Loss  0.16175435483455658
# fps: 2.9733214427999655
# TIMESTEP 49106 / STATE explore / EPSILON 0.0510440049999252 / ACTION 1 / REWARD 0.1 / Q_MAX  4.7416058 / Loss  0.421836256980896
# fps: 4.285354936332252
# TIMESTEP 49107 / STATE explore / EPSILON 0.0510430059999252 / ACTION 0 / REWARD 0.1 / Q_MAX  6.020955 / Loss  0.1924687623977661
# fps: 5.495983793657408
# TIMESTEP 49108 / STATE explore / EPSILON 0.0510420069999252 / ACTION 0 / REWARD 0.1 / Q_MAX  6.7378635 / Loss  0.19784855842590332
# fps: 4.270554755153261
# TIMESTEP 49109 / STATE explore / EPSILON 0.0510410079999252 / ACTION 0 / REWARD -1 / Q_MAX  1.8664877 / Loss  0.1314183622598648
# fps: 3.1903198988055803
# TIMESTEP 49110 / STATE explore / EPSILON 0.051040008999925196 / ACTION 0 / REWARD -1 / Q_MAX  -0.5519321 / Loss  0.37638747692108154
# fps: 3.391932250376652
# TIMESTEP 49111 / STATE explore / EPSILON 0.051039009999925194 / ACTION 1 / REWARD 0.1 / Q_MAX  5.443617 / Loss  0.2214430719614029
# fps: 3.491357560189089
# TIMESTEP 49112 / STATE explore / EPSILON 0.05103801099992519 / ACTION 0 / REWARD 0.1 / Q_MAX  7.4935455 / Loss  0.07520356774330139
# fps: 4.8901361420625
# TIMESTEP 49113 / STATE explore / EPSILON 0.05103701199992519 / ACTION 0 / REWARD 0.1 / Q_MAX  6.167479 / Loss  0.20816901326179504
# fps: 4.820889466648736
# TIMESTEP 49114 / STATE explore / EPSILON 0.05103601299992519 / ACTION 0 / REWARD 0.1 / Q_MAX  7.8969827 / Loss  0.4789166748523712
# fps: 3.8915600833182564
# TIMESTEP 49115 / STATE explore / EPSILON 0.05103501399992519 / ACTION 0 / REWARD -1 / Q_MAX  0.4063821 / Loss  0.1447654366493225
# fps: 3.850362655107236
# TIMESTEP 49116 / STATE explore / EPSILON 0.05103401499992519 / ACTION 1 / REWARD -1 / Q_MAX  4.3416195 / Loss  0.1410922110080719
# fps: 2.857390833985635
# TIMESTEP 49117 / STATE explore / EPSILON 0.051033015999925185 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8525412 / Loss  0.48733919858932495
# ----------Random Action----------
# fps: 4.08692813705515
# TIMESTEP 49118 / STATE explore / EPSILON 0.051032016999925184 / ACTION 1 / REWARD 0.1 / Q_MAX  4.157419 / Loss  0.160740464925766
# fps: 2.8632328566630534
# TIMESTEP 49119 / STATE explore / EPSILON 0.05103101799992518 / ACTION 1 / REWARD 0.1 / Q_MAX  8.633989 / Loss  0.3685857653617859
# fps: 5.370730233201359
# TIMESTEP 49120 / STATE explore / EPSILON 0.05103001899992518 / ACTION 1 / REWARD 0.1 / Q_MAX  4.3596296 / Loss  0.20129135251045227
# fps: 4.968282998663849
# TIMESTEP 49121 / STATE explore / EPSILON 0.05102901999992518 / ACTION 1 / REWARD 0.1 / Q_MAX  6.981863 / Loss  0.19359932839870453
# fps: 2.3866000470002087
# TIMESTEP 49122 / STATE explore / EPSILON 0.05102802099992518 / ACTION 1 / REWARD 0.1 / Q_MAX  7.2303495 / Loss  0.4017050266265869
# fps: 3.306741511025615
# TIMESTEP 49123 / STATE explore / EPSILON 0.051027021999925176 / ACTION 1 / REWARD 0.1 / Q_MAX  7.1159 / Loss  0.28951960802078247
# fps: 7.82414302556373
# TIMESTEP 49124 / STATE explore / EPSILON 0.051026022999925175 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5956284 / Loss  0.8946483135223389
# fps: 5.353448793008601
# TIMESTEP 49125 / STATE explore / EPSILON 0.05102502399992517 / ACTION 1 / REWARD 0.1 / Q_MAX  4.789996 / Loss  0.10009512305259705
# fps: 2.638180906716181
# TIMESTEP 49126 / STATE explore / EPSILON 0.05102402499992517 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9888346 / Loss  0.20480740070343018
# fps: 4.102983887613389
# TIMESTEP 49127 / STATE explore / EPSILON 0.05102302599992517 / ACTION 1 / REWARD 0.1 / Q_MAX  7.1000705 / Loss  0.4459116756916046
# fps: 4.351055111444914
# TIMESTEP 49128 / STATE explore / EPSILON 0.05102202699992517 / ACTION 1 / REWARD 0.1 / Q_MAX  6.6125717 / Loss  0.40100422501564026
# fps: 2.6375040480929157
# TIMESTEP 49129 / STATE explore / EPSILON 0.05102102799992517 / ACTION 1 / REWARD 0.1 / Q_MAX  6.8847494 / Loss  0.43497616052627563
# fps: 4.986997174953154
# TIMESTEP 49130 / STATE explore / EPSILON 0.051020028999925165 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4504482 / Loss  0.171861469745636
# fps: 3.7722462305004565
# TIMESTEP 49131 / STATE explore / EPSILON 0.051019029999925164 / ACTION 1 / REWARD 0.1 / Q_MAX  4.7281504 / Loss  0.3101065158843994
# fps: 4.5612372954715
# TIMESTEP 49132 / STATE explore / EPSILON 0.05101803099992516 / ACTION 1 / REWARD 0.1 / Q_MAX  2.9189074 / Loss  0.2102317065000534
# fps: 2.647145436655826
# TIMESTEP 49133 / STATE explore / EPSILON 0.05101703199992516 / ACTION 1 / REWARD 0.1 / Q_MAX  7.6423464 / Loss  0.2578588128089905
# fps: 4.241657868443301
# TIMESTEP 49134 / STATE explore / EPSILON 0.05101603299992516 / ACTION 1 / REWARD 0.1 / Q_MAX  7.7549224 / Loss  0.22825968265533447
# fps: 3.5537811473458296
# TIMESTEP 49135 / STATE explore / EPSILON 0.05101503399992516 / ACTION 1 / REWARD 0.1 / Q_MAX  8.364201 / Loss  0.10369162261486053
# fps: 3.6370592423082293
# TIMESTEP 49136 / STATE explore / EPSILON 0.051014034999925156 / ACTION 1 / REWARD -1 / Q_MAX  3.1441386 / Loss  0.3356889486312866
# fps: 2.941926071403521
# TIMESTEP 49137 / STATE explore / EPSILON 0.051013035999925155 / ACTION 1 / REWARD -1 / Q_MAX  7.3021393 / Loss  0.25231942534446716
# fps: 4.372865593651151
# TIMESTEP 49138 / STATE explore / EPSILON 0.05101203699992515 / ACTION 1 / REWARD 0.1 / Q_MAX  9.7762985 / Loss  0.3791345953941345
# fps: 4.178051380131289
# TIMESTEP 49139 / STATE explore / EPSILON 0.05101103799992515 / ACTION 1 / REWARD 0.1 / Q_MAX  8.876668 / Loss  0.6929152011871338
# fps: 7.297322595181054
# TIMESTEP 49140 / STATE explore / EPSILON 0.05101003899992515 / ACTION 1 / REWARD 0.1 / Q_MAX  3.8880255 / Loss  0.3451843857765198
# fps: 6.806736135566594
# TIMESTEP 49141 / STATE explore / EPSILON 0.05100903999992515 / ACTION 1 / REWARD 0.1 / Q_MAX  7.156608 / Loss  0.1244056299328804
# fps: 7.469620580037933
# TIMESTEP 49142 / STATE explore / EPSILON 0.05100804099992515 / ACTION 1 / REWARD 0.1 / Q_MAX  7.21942 / Loss  0.25385066866874695
# fps: 7.523226322567685
# TIMESTEP 49143 / STATE explore / EPSILON 0.051007041999925146 / ACTION 1 / REWARD 0.1 / Q_MAX  2.259256 / Loss  0.12997005879878998
# fps: 7.514397969073882
# TIMESTEP 49144 / STATE explore / EPSILON 0.051006042999925144 / ACTION 1 / REWARD 0.1 / Q_MAX  7.9253235 / Loss  0.14740654826164246
# fps: 4.253198033165239
# TIMESTEP 49145 / STATE explore / EPSILON 0.05100504399992514 / ACTION 1 / REWARD 0.1 / Q_MAX  2.9457786 / Loss  0.5675049424171448
# fps: 4.328491567070761
# TIMESTEP 49146 / STATE explore / EPSILON 0.05100404499992514 / ACTION 1 / REWARD 0.1 / Q_MAX  5.2101436 / Loss  0.3979065716266632
# fps: 7.420657443119493
# TIMESTEP 49147 / STATE explore / EPSILON 0.05100304599992514 / ACTION 1 / REWARD 0.1 / Q_MAX  8.022498 / Loss  0.14522893726825714
# fps: 5.962959540399179
# TIMESTEP 49148 / STATE explore / EPSILON 0.05100204699992514 / ACTION 1 / REWARD 0.1 / Q_MAX  9.5605135 / Loss  0.17136496305465698
# fps: 6.026134344033712
# TIMESTEP 49149 / STATE explore / EPSILON 0.051001047999925136 / ACTION 1 / REWARD 0.1 / Q_MAX  6.067415 / Loss  0.22093787789344788
# fps: 5.824564716861129
# TIMESTEP 49150 / STATE explore / EPSILON 0.051000048999925135 / ACTION 1 / REWARD 0.1 / Q_MAX  8.442304 / Loss  0.15856483578681946
# fps: 5.131161780141861
# TIMESTEP 49151 / STATE explore / EPSILON 0.05099904999992513 / ACTION 1 / REWARD 0.1 / Q_MAX  2.864282 / Loss  0.7950153946876526
# fps: 3.413775057156647
# TIMESTEP 49152 / STATE explore / EPSILON 0.05099805099992513 / ACTION 1 / REWARD 0.1 / Q_MAX  7.149922 / Loss  0.4914105236530304
# fps: 6.423818786087329
# TIMESTEP 49153 / STATE explore / EPSILON 0.05099705199992513 / ACTION 1 / REWARD 0.1 / Q_MAX  2.5014927 / Loss  0.31628644466400146
# fps: 5.920671017211614
# TIMESTEP 49154 / STATE explore / EPSILON 0.05099605299992513 / ACTION 1 / REWARD 0.1 / Q_MAX  0.9115312 / Loss  0.7342770099639893
# fps: 5.616910039532467
# TIMESTEP 49155 / STATE explore / EPSILON 0.05099505399992513 / ACTION 1 / REWARD 0.1 / Q_MAX  9.34457 / Loss  0.2607181668281555
# fps: 5.638460276874847
# TIMESTEP 49156 / STATE explore / EPSILON 0.050994054999925126 / ACTION 1 / REWARD 0.1 / Q_MAX  3.1949742 / Loss  0.3572963774204254
# fps: 5.580470566947488
# TIMESTEP 49157 / STATE explore / EPSILON 0.050993055999925124 / ACTION 1 / REWARD 0.1 / Q_MAX  7.6714845 / Loss  0.22714054584503174
# ----------Random Action----------
# fps: 3.6769401378971778
# TIMESTEP 49158 / STATE explore / EPSILON 0.05099205699992512 / ACTION 0 / REWARD 0.1 / Q_MAX  9.703708 / Loss  0.27506160736083984
# fps: 4.847869530793992
# TIMESTEP 49159 / STATE explore / EPSILON 0.05099105799992512 / ACTION 0 / REWARD 0.1 / Q_MAX  8.896923 / Loss  0.22176304459571838
# fps: 6.51162039725147
# TIMESTEP 49160 / STATE explore / EPSILON 0.05099005899992512 / ACTION 0 / REWARD 0.1 / Q_MAX  3.919044 / Loss  0.27860257029533386
# fps: 6.785505244067966
# TIMESTEP 49161 / STATE explore / EPSILON 0.05098905999992512 / ACTION 0 / REWARD 0.1 / Q_MAX  7.1260886 / Loss  0.11889465153217316
# fps: 6.599528594311034
# TIMESTEP 49162 / STATE explore / EPSILON 0.05098806099992512 / ACTION 1 / REWARD 0.1 / Q_MAX  2.662761 / Loss  0.22277143597602844
# fps: 7.328228056657738
# TIMESTEP 49163 / STATE explore / EPSILON 0.050987061999925115 / ACTION 1 / REWARD 0.1 / Q_MAX  8.966157 / Loss  0.234659343957901
# fps: 4.114680811614448
# TIMESTEP 49164 / STATE explore / EPSILON 0.050986062999925114 / ACTION 0 / REWARD 0.1 / Q_MAX  5.82893 / Loss  0.718438446521759
# fps: 3.9422966302104285
# TIMESTEP 49165 / STATE explore / EPSILON 0.05098506399992511 / ACTION 1 / REWARD -1 / Q_MAX  6.926762 / Loss  0.21620163321495056
# fps: 3.4899021500366105
# TIMESTEP 49166 / STATE explore / EPSILON 0.05098406499992511 / ACTION 1 / REWARD -1 / Q_MAX  8.877221 / Loss  0.4896726906299591
# fps: 5.248909685000645
# TIMESTEP 49167 / STATE explore / EPSILON 0.05098306599992511 / ACTION 1 / REWARD 0.1 / Q_MAX  5.091611 / Loss  0.2668263018131256
# fps: 2.832976591475074
# TIMESTEP 49168 / STATE explore / EPSILON 0.05098206699992511 / ACTION 1 / REWARD 0.1 / Q_MAX  9.462212 / Loss  0.34457552433013916
# fps: 5.283350464558518
# TIMESTEP 49169 / STATE explore / EPSILON 0.050981067999925106 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6645213 / Loss  0.19952064752578735
# fps: 5.3918292839696615
# TIMESTEP 49170 / STATE explore / EPSILON 0.050980068999925104 / ACTION 1 / REWARD 0.1 / Q_MAX  9.696302 / Loss  0.36401641368865967
# fps: 4.687279217100065
# TIMESTEP 49171 / STATE explore / EPSILON 0.0509790699999251 / ACTION 1 / REWARD 0.1 / Q_MAX  4.337816 / Loss  0.2268248200416565
# fps: 4.531908525615745
# TIMESTEP 49172 / STATE explore / EPSILON 0.0509780709999251 / ACTION 1 / REWARD 0.1 / Q_MAX  8.924309 / Loss  0.6272774338722229
# fps: 4.425010787423921
# TIMESTEP 49173 / STATE explore / EPSILON 0.0509770719999251 / ACTION 1 / REWARD 0.1 / Q_MAX  4.1321836 / Loss  0.39078488945961
# fps: 4.797970219050245
# TIMESTEP 49174 / STATE explore / EPSILON 0.0509760729999251 / ACTION 1 / REWARD 0.1 / Q_MAX  4.0689774 / Loss  0.16826385259628296
# fps: 4.861997215624497
# TIMESTEP 49175 / STATE explore / EPSILON 0.0509750739999251 / ACTION 1 / REWARD 0.1 / Q_MAX  0.743627 / Loss  0.5082440376281738
# fps: 7.034141792922093
# TIMESTEP 49176 / STATE explore / EPSILON 0.050974074999925095 / ACTION 1 / REWARD 0.1 / Q_MAX  10.065761 / Loss  0.2822815179824829
# fps: 7.223003098054546
# TIMESTEP 49177 / STATE explore / EPSILON 0.050973075999925094 / ACTION 0 / REWARD 0.1 / Q_MAX  8.867016 / Loss  1.0220372676849365
# fps: 7.3138775737961055
# TIMESTEP 49178 / STATE explore / EPSILON 0.05097207699992509 / ACTION 1 / REWARD 0.1 / Q_MAX  9.436307 / Loss  0.10004614293575287
# fps: 7.626742213340559
# TIMESTEP 49179 / STATE explore / EPSILON 0.05097107799992509 / ACTION 0 / REWARD 0.1 / Q_MAX  8.052936 / Loss  0.47887682914733887
# fps: 5.2838296800201565
# TIMESTEP 49180 / STATE explore / EPSILON 0.05097007899992509 / ACTION 1 / REWARD 0.1 / Q_MAX  9.222658 / Loss  0.1292869746685028
# fps: 2.6662615226085005
# TIMESTEP 49181 / STATE explore / EPSILON 0.05096907999992509 / ACTION 1 / REWARD 0.1 / Q_MAX  10.049924 / Loss  0.7976700663566589
# fps: 5.262872336287472
# TIMESTEP 49182 / STATE explore / EPSILON 0.050968080999925086 / ACTION 1 / REWARD 0.1 / Q_MAX  0.062275954 / Loss  0.214833065867424
# fps: 6.470235065083317
# TIMESTEP 49183 / STATE explore / EPSILON 0.050967081999925085 / ACTION 0 / REWARD 0.1 / Q_MAX  3.784246 / Loss  0.2178812474012375
# fps: 3.63765857229214
# TIMESTEP 49184 / STATE explore / EPSILON 0.05096608299992508 / ACTION 1 / REWARD 0.1 / Q_MAX  7.0161524 / Loss  0.31099990010261536
# fps: 5.744764137957483
# TIMESTEP 49185 / STATE explore / EPSILON 0.05096508399992508 / ACTION 0 / REWARD 0.1 / Q_MAX  9.688771 / Loss  0.6385478973388672
# fps: 5.882630806818533
# TIMESTEP 49186 / STATE explore / EPSILON 0.05096408499992508 / ACTION 1 / REWARD 0.1 / Q_MAX  9.550068 / Loss  0.17986053228378296
# fps: 6.215984622703446
# TIMESTEP 49187 / STATE explore / EPSILON 0.05096308599992508 / ACTION 1 / REWARD 0.1 / Q_MAX  9.730062 / Loss  2.199014186859131
# fps: 3.8269057412199228
# TIMESTEP 49188 / STATE explore / EPSILON 0.05096208699992508 / ACTION 1 / REWARD 0.1 / Q_MAX  8.576806 / Loss  0.19915729761123657
# fps: 6.730507174515147
# TIMESTEP 49189 / STATE explore / EPSILON 0.050961087999925075 / ACTION 1 / REWARD 0.1 / Q_MAX  8.538842 / Loss  0.5720430612564087
# fps: 7.312525933700386
# TIMESTEP 49190 / STATE explore / EPSILON 0.050960088999925074 / ACTION 0 / REWARD 0.1 / Q_MAX  9.968509 / Loss  0.4803817570209503
# fps: 5.317780944604758
# TIMESTEP 49191 / STATE explore / EPSILON 0.05095908999992507 / ACTION 0 / REWARD -1 / Q_MAX  6.192338 / Loss  0.2975161075592041
# fps: 3.911509673616849
# TIMESTEP 49192 / STATE explore / EPSILON 0.05095809099992507 / ACTION 0 / REWARD -1 / Q_MAX  9.203572 / Loss  0.3927510380744934
# fps: 2.589348264941383
# TIMESTEP 49193 / STATE explore / EPSILON 0.05095709199992507 / ACTION 0 / REWARD -1 / Q_MAX  1.9047066 / Loss  0.7131994962692261
# ----------Random Action----------
# fps: 3.8881726171604862
# TIMESTEP 49194 / STATE explore / EPSILON 0.05095609299992507 / ACTION 1 / REWARD 0.1 / Q_MAX  5.7656794 / Loss  0.2318115532398224
# fps: 4.044499772911144
# TIMESTEP 49195 / STATE explore / EPSILON 0.050955093999925066 / ACTION 1 / REWARD 0.1 / Q_MAX  8.420949 / Loss  0.3743149936199188
# fps: 3.937433700262289
# TIMESTEP 49196 / STATE explore / EPSILON 0.050954094999925065 / ACTION 0 / REWARD 0.1 / Q_MAX  3.1442707 / Loss  0.5436950325965881
# fps: 3.9977048699076803
# TIMESTEP 49197 / STATE explore / EPSILON 0.05095309599992506 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9475892 / Loss  0.2725374102592468
# fps: 4.383129206203235
# TIMESTEP 49198 / STATE explore / EPSILON 0.05095209699992506 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.5619065 / Loss  0.2872488498687744
# fps: 7.830277866973334
# TIMESTEP 49199 / STATE explore / EPSILON 0.05095109799992506 / ACTION 1 / REWARD 0.1 / Q_MAX  4.0132785 / Loss  0.36625438928604126
# fps: 7.635447462317047
# TIMESTEP 49200 / STATE explore / EPSILON 0.05095009899992506 / ACTION 0 / REWARD 0.1 / Q_MAX  7.870702 / Loss  0.5464657545089722
# fps: 7.150230908102155
# TIMESTEP 49201 / STATE explore / EPSILON 0.05094909999992506 / ACTION 0 / REWARD 0.1 / Q_MAX  8.578822 / Loss  0.7205246686935425
# fps: 3.708652275828042
# TIMESTEP 49202 / STATE explore / EPSILON 0.050948100999925056 / ACTION 0 / REWARD 0.1 / Q_MAX  9.823878 / Loss  0.3923109173774719
# fps: 6.646832207383883
# TIMESTEP 49203 / STATE explore / EPSILON 0.050947101999925054 / ACTION 1 / REWARD 0.1 / Q_MAX  7.381683 / Loss  0.18804000318050385
# fps: 3.692136512882809
# TIMESTEP 49204 / STATE explore / EPSILON 0.05094610299992505 / ACTION 1 / REWARD 0.1 / Q_MAX  6.6692176 / Loss  0.11852270364761353
# fps: 5.0817565561902915
# TIMESTEP 49205 / STATE explore / EPSILON 0.05094510399992505 / ACTION 1 / REWARD 0.1 / Q_MAX  1.514348 / Loss  0.8868546485900879
# fps: 4.224151857021716
# TIMESTEP 49206 / STATE explore / EPSILON 0.05094410499992505 / ACTION 1 / REWARD 0.1 / Q_MAX  7.7331085 / Loss  0.7209852933883667
# fps: 3.8477523379318317
# TIMESTEP 49207 / STATE explore / EPSILON 0.05094310599992505 / ACTION 1 / REWARD 0.1 / Q_MAX  8.853846 / Loss  0.307548463344574
# fps: 4.142931647570131
# TIMESTEP 49208 / STATE explore / EPSILON 0.050942106999925046 / ACTION 1 / REWARD 0.1 / Q_MAX  7.193772 / Loss  0.4161195755004883
# fps: 3.6035520853380256
# TIMESTEP 49209 / STATE explore / EPSILON 0.050941107999925045 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8473927 / Loss  0.31799763441085815
# fps: 4.644777772240771
# TIMESTEP 49210 / STATE explore / EPSILON 0.05094010899992504 / ACTION 1 / REWARD 0.1 / Q_MAX  3.7981856 / Loss  0.7613975405693054
# fps: 3.7333409288348975
# TIMESTEP 49211 / STATE explore / EPSILON 0.05093910999992504 / ACTION 1 / REWARD 0.1 / Q_MAX  9.48349 / Loss  1.117743730545044
# fps: 3.6253740502882628
# TIMESTEP 49212 / STATE explore / EPSILON 0.05093811099992504 / ACTION 1 / REWARD 0.1 / Q_MAX  9.700157 / Loss  0.6663858890533447
# fps: 3.9497437655261516
# TIMESTEP 49213 / STATE explore / EPSILON 0.05093711199992504 / ACTION 0 / REWARD 0.1 / Q_MAX  3.9568372 / Loss  0.486606627702713
# fps: 5.352130360993786
# TIMESTEP 49214 / STATE explore / EPSILON 0.05093611299992504 / ACTION 1 / REWARD 0.1 / Q_MAX  5.7424946 / Loss  0.49517714977264404
# fps: 3.7588758244909664
# TIMESTEP 49215 / STATE explore / EPSILON 0.050935113999925036 / ACTION 1 / REWARD -1 / Q_MAX  8.855109 / Loss  0.537650465965271
# fps: 4.778984021074316
# TIMESTEP 49216 / STATE explore / EPSILON 0.050934114999925034 / ACTION 1 / REWARD -1 / Q_MAX  2.0564332 / Loss  0.1819169521331787
# fps: 3.8813183681136807
# TIMESTEP 49217 / STATE explore / EPSILON 0.05093311599992503 / ACTION 1 / REWARD -1 / Q_MAX  7.256219 / Loss  0.8800687193870544
# fps: 5.078231053662623
# TIMESTEP 49218 / STATE explore / EPSILON 0.05093211699992503 / ACTION 0 / REWARD 0.1 / Q_MAX  8.858556 / Loss  0.24005761742591858
# fps: 4.002893632291104
# TIMESTEP 49219 / STATE explore / EPSILON 0.05093111799992503 / ACTION 0 / REWARD 0.1 / Q_MAX  6.496502 / Loss  0.32475364208221436
# fps: 4.324301140897665
# TIMESTEP 49220 / STATE explore / EPSILON 0.05093011899992503 / ACTION 1 / REWARD 0.1 / Q_MAX  7.573304 / Loss  0.3260950446128845
# fps: 5.287686533765496
# TIMESTEP 49221 / STATE explore / EPSILON 0.05092911999992503 / ACTION 1 / REWARD 0.1 / Q_MAX  9.038759 / Loss  0.6766153573989868
# fps: 5.644728200600769
# TIMESTEP 49222 / STATE explore / EPSILON 0.050928120999925025 / ACTION 1 / REWARD 0.1 / Q_MAX  3.1206455 / Loss  0.42160564661026
# fps: 4.778396015329861
# TIMESTEP 49223 / STATE explore / EPSILON 0.050927121999925024 / ACTION 1 / REWARD 0.1 / Q_MAX  8.433566 / Loss  0.27531617879867554
# fps: 4.048008956318644
# TIMESTEP 49224 / STATE explore / EPSILON 0.05092612299992502 / ACTION 1 / REWARD 0.1 / Q_MAX  7.0017705 / Loss  0.39049169421195984
# fps: 4.292455282489403
# TIMESTEP 49225 / STATE explore / EPSILON 0.05092512399992502 / ACTION 1 / REWARD 0.1 / Q_MAX  7.8006964 / Loss  0.3159066438674927
# fps: 2.62798861914032
# TIMESTEP 49226 / STATE explore / EPSILON 0.05092412499992502 / ACTION 0 / REWARD 0.1 / Q_MAX  2.6131003 / Loss  0.17245948314666748
# fps: 4.040062494100241
# TIMESTEP 49227 / STATE explore / EPSILON 0.05092312599992502 / ACTION 0 / REWARD 0.1 / Q_MAX  8.66932 / Loss  0.26409488916397095
# ----------Random Action----------
# fps: 3.0623359972898028
# TIMESTEP 49228 / STATE explore / EPSILON 0.050922126999925016 / ACTION 0 / REWARD 0.1 / Q_MAX  7.026516 / Loss  0.15147894620895386
# fps: 6.543702649742265
# TIMESTEP 49229 / STATE explore / EPSILON 0.050921127999925014 / ACTION 0 / REWARD 0.1 / Q_MAX  2.3692787 / Loss  0.5999184846878052
# fps: 5.871842398517166
# TIMESTEP 49230 / STATE explore / EPSILON 0.05092012899992501 / ACTION 1 / REWARD 0.1 / Q_MAX  7.6758633 / Loss  0.11149584501981735
# fps: 3.372784709864238
# TIMESTEP 49231 / STATE explore / EPSILON 0.05091912999992501 / ACTION 1 / REWARD 0.1 / Q_MAX  3.0834951 / Loss  0.31776607036590576
# fps: 4.09779678784936
# TIMESTEP 49232 / STATE explore / EPSILON 0.05091813099992501 / ACTION 1 / REWARD 0.1 / Q_MAX  4.4718904 / Loss  0.5656448602676392
# fps: 4.412855059686009
# TIMESTEP 49233 / STATE explore / EPSILON 0.05091713199992501 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.12776741 / Loss  0.3117179274559021
# fps: 5.461226668749959
# TIMESTEP 49234 / STATE explore / EPSILON 0.05091613299992501 / ACTION 1 / REWARD 0.1 / Q_MAX  6.3967476 / Loss  0.394140362739563
# fps: 7.528019829169052
# TIMESTEP 49235 / STATE explore / EPSILON 0.050915133999925005 / ACTION 1 / REWARD 0.1 / Q_MAX  7.0984178 / Loss  0.7986633777618408
# fps: 6.452983865632582
# TIMESTEP 49236 / STATE explore / EPSILON 0.050914134999925004 / ACTION 1 / REWARD 0.1 / Q_MAX  2.1495464 / Loss  0.4802638292312622
# fps: 4.709304075038006
# TIMESTEP 49237 / STATE explore / EPSILON 0.050913135999925 / ACTION 0 / REWARD 0.1 / Q_MAX  5.437959 / Loss  0.19909995794296265
# fps: 5.449610993020222
# TIMESTEP 49238 / STATE explore / EPSILON 0.050912136999925 / ACTION 1 / REWARD 0.1 / Q_MAX  6.153816 / Loss  0.6453168392181396
# fps: 5.329849824511466
# TIMESTEP 49239 / STATE explore / EPSILON 0.050911137999925 / ACTION 1 / REWARD 0.1 / Q_MAX  6.03599 / Loss  0.15979760885238647
# fps: 5.728248845282937
# TIMESTEP 49240 / STATE explore / EPSILON 0.050910138999925 / ACTION 1 / REWARD 0.1 / Q_MAX  7.550637 / Loss  0.2305571287870407
# fps: 4.205068976580045
# TIMESTEP 49241 / STATE explore / EPSILON 0.050909139999924996 / ACTION 1 / REWARD 0.1 / Q_MAX  2.428536 / Loss  0.17327848076820374
# fps: 4.321298314877623
# TIMESTEP 49242 / STATE explore / EPSILON 0.050908140999924995 / ACTION 0 / REWARD -1 / Q_MAX  6.507714 / Loss  0.2076864242553711
# fps: 4.717858962663676
# TIMESTEP 49243 / STATE explore / EPSILON 0.05090714199992499 / ACTION 0 / REWARD -1 / Q_MAX  -0.95604795 / Loss  0.41105884313583374
# fps: 4.777840809417382
# TIMESTEP 49244 / STATE explore / EPSILON 0.05090614299992499 / ACTION 0 / REWARD -1 / Q_MAX  5.092192 / Loss  0.2529723048210144
# fps: 5.242748931276718
# TIMESTEP 49245 / STATE explore / EPSILON 0.05090514399992499 / ACTION 0 / REWARD 0.1 / Q_MAX  1.081792 / Loss  0.5287531018257141
# fps: 5.477230137991645
# TIMESTEP 49246 / STATE explore / EPSILON 0.05090414499992499 / ACTION 1 / REWARD 0.1 / Q_MAX  4.2929835 / Loss  0.5081686973571777
# fps: 6.141990657353308
# TIMESTEP 49247 / STATE explore / EPSILON 0.05090314599992499 / ACTION 1 / REWARD 0.1 / Q_MAX  6.61141 / Loss  0.26193854212760925
# fps: 6.75986023543367
# TIMESTEP 49248 / STATE explore / EPSILON 0.050902146999924985 / ACTION 1 / REWARD 0.1 / Q_MAX  0.5695598 / Loss  0.12319189310073853
# fps: 6.223972577330296
# TIMESTEP 49249 / STATE explore / EPSILON 0.050901147999924984 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5002761 / Loss  0.18826787173748016
# fps: 4.643451093966054
# TIMESTEP 49250 / STATE explore / EPSILON 0.05090014899992498 / ACTION 1 / REWARD 0.1 / Q_MAX  5.4476833 / Loss  0.2555941045284271
# fps: 4.447858629005062
# TIMESTEP 49251 / STATE explore / EPSILON 0.05089914999992498 / ACTION 1 / REWARD 0.1 / Q_MAX  5.4940844 / Loss  0.4267868399620056
# fps: 4.603040156803698
# TIMESTEP 49252 / STATE explore / EPSILON 0.05089815099992498 / ACTION 1 / REWARD 0.1 / Q_MAX  6.5444355 / Loss  0.4769846498966217
# fps: 4.44269037624551
# TIMESTEP 49253 / STATE explore / EPSILON 0.05089715199992498 / ACTION 1 / REWARD 0.1 / Q_MAX  7.697479 / Loss  0.11344989389181137
# fps: 4.013810949234809
# TIMESTEP 49254 / STATE explore / EPSILON 0.050896152999924976 / ACTION 1 / REWARD 0.1 / Q_MAX  1.0727491 / Loss  0.35199135541915894
# fps: 7.227845003773923
# TIMESTEP 49255 / STATE explore / EPSILON 0.050895153999924975 / ACTION 1 / REWARD 0.1 / Q_MAX  3.8949826 / Loss  0.23653070628643036
# fps: 7.51037481109034
# TIMESTEP 49256 / STATE explore / EPSILON 0.05089415499992497 / ACTION 1 / REWARD 0.1 / Q_MAX  4.7156525 / Loss  0.2102699875831604
# fps: 5.4906956864377605
# TIMESTEP 49257 / STATE explore / EPSILON 0.05089315599992497 / ACTION 1 / REWARD 0.1 / Q_MAX  3.4257395 / Loss  0.1177816390991211
# fps: 4.241554921829177
# TIMESTEP 49258 / STATE explore / EPSILON 0.05089215699992497 / ACTION 1 / REWARD 0.1 / Q_MAX  8.57676 / Loss  0.34475889801979065
# fps: 7.444787606409792
# TIMESTEP 49259 / STATE explore / EPSILON 0.05089115799992497 / ACTION 1 / REWARD 0.1 / Q_MAX  3.7870307 / Loss  0.13287165760993958
# fps: 6.813802066411073
# TIMESTEP 49260 / STATE explore / EPSILON 0.05089015899992497 / ACTION 1 / REWARD 0.1 / Q_MAX  8.576372 / Loss  0.721541166305542
# fps: 3.4803920592403768
# TIMESTEP 49261 / STATE explore / EPSILON 0.050889159999924966 / ACTION 1 / REWARD 0.1 / Q_MAX  4.8320847 / Loss  1.06534743309021
# fps: 2.9147291562283053
# TIMESTEP 49262 / STATE explore / EPSILON 0.050888160999924964 / ACTION 1 / REWARD 0.1 / Q_MAX  3.0018733 / Loss  0.37531542778015137
# fps: 3.9410408893290474
# TIMESTEP 49263 / STATE explore / EPSILON 0.05088716199992496 / ACTION 1 / REWARD 0.1 / Q_MAX  8.442414 / Loss  0.372195839881897
# fps: 2.4365429390687665
# TIMESTEP 49264 / STATE explore / EPSILON 0.05088616299992496 / ACTION 1 / REWARD 0.1 / Q_MAX  10.828688 / Loss  0.20203962922096252
# fps: 4.319015574720042
# TIMESTEP 49265 / STATE explore / EPSILON 0.05088516399992496 / ACTION 1 / REWARD 0.1 / Q_MAX  2.2848198 / Loss  0.2595837116241455
# fps: 5.600036316153479
# TIMESTEP 49266 / STATE explore / EPSILON 0.05088416499992496 / ACTION 1 / REWARD 0.1 / Q_MAX  7.272174 / Loss  0.44065117835998535
# fps: 4.861997215624497
# TIMESTEP 49267 / STATE explore / EPSILON 0.050883165999924956 / ACTION 1 / REWARD 0.1 / Q_MAX  8.334552 / Loss  0.6212974786758423
# fps: 6.488973875805648
# TIMESTEP 49268 / STATE explore / EPSILON 0.050882166999924955 / ACTION 1 / REWARD 0.1 / Q_MAX  6.937152 / Loss  0.313406765460968
# ----------Random Action----------
# fps: 4.35638323838408
# TIMESTEP 49269 / STATE explore / EPSILON 0.05088116799992495 / ACTION 1 / REWARD -1 / Q_MAX  8.517471 / Loss  0.3750963807106018
# fps: 3.558068059873687
# TIMESTEP 49270 / STATE explore / EPSILON 0.05088016899992495 / ACTION 1 / REWARD -1 / Q_MAX  7.458311 / Loss  0.23132169246673584
# fps: 4.309545557760062
# TIMESTEP 49271 / STATE explore / EPSILON 0.05087916999992495 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0173953 / Loss  0.23287734389305115
# fps: 4.760007036219507
# TIMESTEP 49272 / STATE explore / EPSILON 0.05087817099992495 / ACTION 1 / REWARD 0.1 / Q_MAX  5.398833 / Loss  0.6547436118125916
# fps: 2.761952612964169
# TIMESTEP 49273 / STATE explore / EPSILON 0.05087717199992495 / ACTION 1 / REWARD 0.1 / Q_MAX  9.310849 / Loss  0.43180209398269653
# fps: 5.816132566040352
# TIMESTEP 49274 / STATE explore / EPSILON 0.050876172999924946 / ACTION 1 / REWARD 0.1 / Q_MAX  3.020315 / Loss  0.5825499892234802
# fps: 7.593823269018034
# TIMESTEP 49275 / STATE explore / EPSILON 0.050875173999924944 / ACTION 0 / REWARD 0.1 / Q_MAX  7.3214135 / Loss  0.42370158433914185
# fps: 7.595198386182594
# TIMESTEP 49276 / STATE explore / EPSILON 0.05087417499992494 / ACTION 1 / REWARD 0.1 / Q_MAX  7.2286587 / Loss  0.2508232295513153
# fps: 6.883649481219864
# TIMESTEP 49277 / STATE explore / EPSILON 0.05087317599992494 / ACTION 0 / REWARD 0.1 / Q_MAX  8.6817665 / Loss  0.4715176224708557
# fps: 4.644566892861572
# TIMESTEP 49278 / STATE explore / EPSILON 0.05087217699992494 / ACTION 0 / REWARD 0.1 / Q_MAX  8.734372 / Loss  0.4221746623516083
# fps: 5.056332917427653
# TIMESTEP 49279 / STATE explore / EPSILON 0.05087117799992494 / ACTION 1 / REWARD 0.1 / Q_MAX  1.830458 / Loss  0.1114928275346756
# fps: 3.9722511864275156
# TIMESTEP 49280 / STATE explore / EPSILON 0.050870178999924937 / ACTION 1 / REWARD 0.1 / Q_MAX  6.133188 / Loss  0.22474747896194458
# fps: 2.724072849703647
# TIMESTEP 49281 / STATE explore / EPSILON 0.050869179999924935 / ACTION 1 / REWARD 0.1 / Q_MAX  6.526013 / Loss  0.26836052536964417
# fps: 6.880600540696606
# TIMESTEP 49282 / STATE explore / EPSILON 0.050868180999924933 / ACTION 1 / REWARD 0.1 / Q_MAX  7.4939637 / Loss  0.19877515733242035
# fps: 6.142854213715997
# TIMESTEP 49283 / STATE explore / EPSILON 0.05086718199992493 / ACTION 1 / REWARD 0.1 / Q_MAX  7.0623565 / Loss  0.5016985535621643
# fps: 2.8871319242434046
# TIMESTEP 49284 / STATE explore / EPSILON 0.05086618299992493 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4663336 / Loss  0.22119511663913727
# fps: 2.7571340767984327
# TIMESTEP 49285 / STATE explore / EPSILON 0.05086518399992493 / ACTION 1 / REWARD 0.1 / Q_MAX  7.658896 / Loss  0.2748342454433441
# fps: 5.903072218023473
# TIMESTEP 49286 / STATE explore / EPSILON 0.05086418499992493 / ACTION 1 / REWARD 0.1 / Q_MAX  8.133511 / Loss  0.27038073539733887
# fps: 5.6461643461275965
# TIMESTEP 49287 / STATE explore / EPSILON 0.050863185999924926 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4561771 / Loss  0.2864874601364136
# fps: 5.468147157330162
# TIMESTEP 49288 / STATE explore / EPSILON 0.050862186999924924 / ACTION 1 / REWARD 0.1 / Q_MAX  6.8871164 / Loss  0.27251046895980835
# fps: 4.942627722431587
# TIMESTEP 49289 / STATE explore / EPSILON 0.05086118799992492 / ACTION 1 / REWARD 0.1 / Q_MAX  4.0016646 / Loss  0.20211130380630493
# fps: 5.4443198338525445
# TIMESTEP 49290 / STATE explore / EPSILON 0.05086018899992492 / ACTION 1 / REWARD 0.1 / Q_MAX  7.7139454 / Loss  0.31267979741096497
# fps: 6.573000622148811
# TIMESTEP 49291 / STATE explore / EPSILON 0.05085918999992492 / ACTION 1 / REWARD 0.1 / Q_MAX  8.096691 / Loss  0.14134979248046875
# fps: 3.7708896550794084
# TIMESTEP 49292 / STATE explore / EPSILON 0.05085819099992492 / ACTION 1 / REWARD 0.1 / Q_MAX  8.132934 / Loss  0.40598708391189575
# fps: 5.491680589088662
# TIMESTEP 49293 / STATE explore / EPSILON 0.05085719199992492 / ACTION 1 / REWARD 0.1 / Q_MAX  3.8942182 / Loss  0.3297198414802551
# fps: 6.723558963935225
# TIMESTEP 49294 / STATE explore / EPSILON 0.050856192999924915 / ACTION 1 / REWARD 0.1 / Q_MAX  0.65195805 / Loss  0.42022183537483215
# fps: 5.2109758006604565
# TIMESTEP 49295 / STATE explore / EPSILON 0.050855193999924914 / ACTION 0 / REWARD -1 / Q_MAX  3.692415 / Loss  0.2781583070755005
# fps: 6.747593307593307
# TIMESTEP 49296 / STATE explore / EPSILON 0.05085419499992491 / ACTION 0 / REWARD -1 / Q_MAX  1.4914343 / Loss  0.410340279340744
# fps: 3.466684960355867
# TIMESTEP 49297 / STATE explore / EPSILON 0.05085319599992491 / ACTION 0 / REWARD -1 / Q_MAX  -0.5726222 / Loss  0.17748621106147766
# fps: 3.4452965335961885
# TIMESTEP 49298 / STATE explore / EPSILON 0.05085219699992491 / ACTION 0 / REWARD 0.1 / Q_MAX  7.2045894 / Loss  0.17792537808418274
# fps: 3.7062501546368067
# TIMESTEP 49299 / STATE explore / EPSILON 0.05085119799992491 / ACTION 0 / REWARD 0.1 / Q_MAX  0.9896675 / Loss  0.3285815715789795
# fps: 4.3649608753432965
# TIMESTEP 49300 / STATE explore / EPSILON 0.050850198999924906 / ACTION 0 / REWARD 0.1 / Q_MAX  6.7007213 / Loss  0.25305673480033875
# fps: 5.740392656005146
# TIMESTEP 49301 / STATE explore / EPSILON 0.050849199999924904 / ACTION 0 / REWARD 0.1 / Q_MAX  1.602228 / Loss  0.1106027215719223
# fps: 3.1021490106977185
# TIMESTEP 49302 / STATE explore / EPSILON 0.0508482009999249 / ACTION 0 / REWARD 0.1 / Q_MAX  6.751588 / Loss  2.3233184814453125
# fps: 3.29908947325367
# TIMESTEP 49303 / STATE explore / EPSILON 0.0508472019999249 / ACTION 0 / REWARD 0.1 / Q_MAX  2.926308 / Loss  0.25067251920700073
# fps: 6.226541194773885
# TIMESTEP 49304 / STATE explore / EPSILON 0.0508462029999249 / ACTION 0 / REWARD 0.1 / Q_MAX  0.7962575 / Loss  0.08135655522346497
# fps: 5.797505622232943
# TIMESTEP 49305 / STATE explore / EPSILON 0.0508452039999249 / ACTION 0 / REWARD 0.1 / Q_MAX  0.4196058 / Loss  0.46012261509895325
# fps: 5.804389372399181
# TIMESTEP 49306 / STATE explore / EPSILON 0.0508442049999249 / ACTION 0 / REWARD 0.1 / Q_MAX  7.9577594 / Loss  0.3541645407676697
# fps: 3.065169222494402
# TIMESTEP 49307 / STATE explore / EPSILON 0.050843205999924895 / ACTION 0 / REWARD 0.1 / Q_MAX  6.9187093 / Loss  0.3950744867324829
# fps: 3.014039346387475
# TIMESTEP 49308 / STATE explore / EPSILON 0.050842206999924894 / ACTION 0 / REWARD 0.1 / Q_MAX  1.0984482 / Loss  0.5448813438415527
# ...
# fps: 3.8970995007725806
# TIMESTEP 49899 / STATE explore / EPSILON 0.05025179799992399 / ACTION 1 / REWARD 0.1 / Q_MAX  9.372107 / Loss  0.5380146503448486
# ----------Random Action----------
# fps: 4.933210070828894
# TIMESTEP 49900 / STATE explore / EPSILON 0.05025079899992399 / ACTION 0 / REWARD 0.1 / Q_MAX  4.1093273 / Loss  0.30520784854888916
# fps: 3.5719034037925517
# TIMESTEP 49901 / STATE explore / EPSILON 0.05024979999992399 / ACTION 1 / REWARD 0.1 / Q_MAX  6.5057597 / Loss  0.16634228825569153
# fps: 2.690960976836573
# TIMESTEP 49902 / STATE explore / EPSILON 0.05024880099992399 / ACTION 1 / REWARD 0.1 / Q_MAX  3.6254892 / Loss  0.4590008854866028
# ----------Random Action----------
# fps: 4.753425697690891
# TIMESTEP 49903 / STATE explore / EPSILON 0.050247801999923986 / ACTION 0 / REWARD 0.1 / Q_MAX  2.7738774 / Loss  0.2366180419921875
# ----------Random Action----------
# fps: 3.948070725021838
# TIMESTEP 49904 / STATE explore / EPSILON 0.050246802999923984 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6382258 / Loss  0.2652556002140045
# fps: 5.745692755116159
# TIMESTEP 49905 / STATE explore / EPSILON 0.05024580399992398 / ACTION 1 / REWARD 0.1 / Q_MAX  8.767355 / Loss  0.3443012237548828
# fps: 4.343309933902389
# TIMESTEP 49906 / STATE explore / EPSILON 0.05024480499992398 / ACTION 1 / REWARD -1 / Q_MAX  9.130992 / Loss  0.451643168926239
# fps: 4.0810864983624295
# TIMESTEP 49907 / STATE explore / EPSILON 0.05024380599992398 / ACTION 1 / REWARD -1 / Q_MAX  1.324759 / Loss  0.45074135065078735
# fps: 6.116606681405346
# TIMESTEP 49908 / STATE explore / EPSILON 0.05024280699992398 / ACTION 1 / REWARD -1 / Q_MAX  8.102509 / Loss  0.20374172925949097
# ----------Random Action----------
# fps: 3.427068940864059
# TIMESTEP 49909 / STATE explore / EPSILON 0.050241807999923976 / ACTION 0 / REWARD 0.1 / Q_MAX  7.1951666 / Loss  0.1557764708995819
# fps: 4.302816735246173
# TIMESTEP 49910 / STATE explore / EPSILON 0.050240808999923975 / ACTION 1 / REWARD 0.1 / Q_MAX  7.7289357 / Loss  0.1045326292514801
# fps: 2.665156901804919
# TIMESTEP 49911 / STATE explore / EPSILON 0.05023980999992397 / ACTION 1 / REWARD 0.1 / Q_MAX  8.190949 / Loss  0.6465559005737305
# fps: 5.048378593730065
# TIMESTEP 49912 / STATE explore / EPSILON 0.05023881099992397 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0078604 / Loss  0.25687119364738464
# fps: 4.7542177305639814
# TIMESTEP 49913 / STATE explore / EPSILON 0.05023781199992397 / ACTION 1 / REWARD 0.1 / Q_MAX  1.8185027 / Loss  0.3259931802749634
# fps: 7.154389891105592
# TIMESTEP 49914 / STATE explore / EPSILON 0.05023681299992397 / ACTION 1 / REWARD 0.1 / Q_MAX  6.780551 / Loss  0.3407740592956543
# fps: 3.4668912736389057
# TIMESTEP 49915 / STATE explore / EPSILON 0.05023581399992397 / ACTION 1 / REWARD 0.1 / Q_MAX  3.0564692 / Loss  0.2654208540916443
# fps: 4.418386910555745
# TIMESTEP 49916 / STATE explore / EPSILON 0.050234814999923966 / ACTION 1 / REWARD 0.1 / Q_MAX  6.5007095 / Loss  0.27636295557022095
# fps: 3.5046457840345457
# TIMESTEP 49917 / STATE explore / EPSILON 0.050233815999923964 / ACTION 1 / REWARD 0.1 / Q_MAX  6.6673536 / Loss  0.29034334421157837
# ----------Random Action----------
# fps: 4.541393632548409
# TIMESTEP 49918 / STATE explore / EPSILON 0.05023281699992396 / ACTION 1 / REWARD 0.1 / Q_MAX  7.316968 / Loss  0.23075991868972778
# fps: 2.562421037454822
# TIMESTEP 49919 / STATE explore / EPSILON 0.05023181799992396 / ACTION 1 / REWARD 0.1 / Q_MAX  7.70699 / Loss  0.33669543266296387
# fps: 4.065291959660184
# TIMESTEP 49920 / STATE explore / EPSILON 0.05023081899992396 / ACTION 1 / REWARD 0.1 / Q_MAX  9.361473 / Loss  1.9129955768585205
# fps: 2.7873537476358385
# TIMESTEP 49921 / STATE explore / EPSILON 0.05022981999992396 / ACTION 1 / REWARD 0.1 / Q_MAX  7.0817795 / Loss  0.17450645565986633
# fps: 3.1418666458921987
# TIMESTEP 49922 / STATE explore / EPSILON 0.05022882099992396 / ACTION 1 / REWARD 0.1 / Q_MAX  2.0755024 / Loss  0.5936523675918579
# fps: 2.873925096989655
# TIMESTEP 49923 / STATE explore / EPSILON 0.050227821999923955 / ACTION 1 / REWARD 0.1 / Q_MAX  5.8735003 / Loss  0.16061252355575562
# fps: 6.25906222346247
# TIMESTEP 49924 / STATE explore / EPSILON 0.050226822999923953 / ACTION 1 / REWARD 0.1 / Q_MAX  7.41284 / Loss  0.15057320892810822
# fps: 5.702835030871122
# TIMESTEP 49925 / STATE explore / EPSILON 0.05022582399992395 / ACTION 1 / REWARD 0.1 / Q_MAX  7.3390408 / Loss  0.16075178980827332
# fps: 4.205933405867223
# TIMESTEP 49926 / STATE explore / EPSILON 0.05022482499992395 / ACTION 1 / REWARD 0.1 / Q_MAX  7.2032905 / Loss  0.17580266296863556
# fps: 4.356690941461078
# TIMESTEP 49927 / STATE explore / EPSILON 0.05022382599992395 / ACTION 1 / REWARD 0.1 / Q_MAX  6.989628 / Loss  0.2201826572418213
# fps: 3.2276837314675584
# TIMESTEP 49928 / STATE explore / EPSILON 0.05022282699992395 / ACTION 1 / REWARD 0.1 / Q_MAX  4.3015065 / Loss  0.1369476616382599
# fps: 2.9219253214477043
# TIMESTEP 49929 / STATE explore / EPSILON 0.050221827999923946 / ACTION 0 / REWARD -1 / Q_MAX  7.767966 / Loss  0.5691577196121216
# fps: 3.8079183345150884
# TIMESTEP 49930 / STATE explore / EPSILON 0.050220828999923944 / ACTION 1 / REWARD 0.1 / Q_MAX  2.6740673 / Loss  0.16209492087364197
# fps: 3.1541195350229283
# TIMESTEP 49931 / STATE explore / EPSILON 0.05021982999992394 / ACTION 1 / REWARD 0.1 / Q_MAX  7.4612474 / Loss  0.3430519104003906
# fps: 5.733408971300859
# TIMESTEP 49932 / STATE explore / EPSILON 0.05021883099992394 / ACTION 1 / REWARD 0.1 / Q_MAX  3.025668 / Loss  0.11984288692474365
# fps: 6.650774043881779
# TIMESTEP 49933 / STATE explore / EPSILON 0.05021783199992394 / ACTION 1 / REWARD 0.1 / Q_MAX  5.8756742 / Loss  0.11935064941644669
# fps: 6.248646522673166
# TIMESTEP 49934 / STATE explore / EPSILON 0.05021683299992394 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4067794 / Loss  0.17767539620399475
# fps: 3.6133434184885704
# TIMESTEP 49935 / STATE explore / EPSILON 0.05021583399992394 / ACTION 1 / REWARD 0.1 / Q_MAX  4.3032603 / Loss  0.16538015007972717
# fps: 4.8103071194037215
# TIMESTEP 49936 / STATE explore / EPSILON 0.050214834999923935 / ACTION 1 / REWARD 0.1 / Q_MAX  6.872361 / Loss  0.5047165155410767
# fps: 3.2419515535737338
# TIMESTEP 49937 / STATE explore / EPSILON 0.050213835999923934 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9318578 / Loss  0.21025781333446503
# fps: 6.016893132574366
# TIMESTEP 49938 / STATE explore / EPSILON 0.05021283699992393 / ACTION 1 / REWARD 0.1 / Q_MAX  6.5473614 / Loss  0.15528717637062073
# fps: 5.921582136584649
# TIMESTEP 49939 / STATE explore / EPSILON 0.05021183799992393 / ACTION 1 / REWARD 0.1 / Q_MAX  6.1088715 / Loss  0.17662787437438965
# fps: 2.9429044937434483
# TIMESTEP 49940 / STATE explore / EPSILON 0.05021083899992393 / ACTION 1 / REWARD 0.1 / Q_MAX  7.5621567 / Loss  0.19985994696617126
# fps: 3.0192638684231934
# TIMESTEP 49941 / STATE explore / EPSILON 0.05020983999992393 / ACTION 1 / REWARD 0.1 / Q_MAX  2.5023506 / Loss  0.12981408834457397
# fps: 6.811312389876337
# TIMESTEP 49942 / STATE explore / EPSILON 0.050208840999923926 / ACTION 1 / REWARD 0.1 / Q_MAX  5.8210044 / Loss  0.1613450050354004
# fps: 4.216529326077755
# TIMESTEP 49943 / STATE explore / EPSILON 0.050207841999923924 / ACTION 1 / REWARD 0.1 / Q_MAX  5.663668 / Loss  0.8905033469200134
# fps: 4.374662589228722
# TIMESTEP 49944 / STATE explore / EPSILON 0.05020684299992392 / ACTION 1 / REWARD 0.1 / Q_MAX  6.587387 / Loss  0.14510014653205872
# fps: 2.8490100170018007
# TIMESTEP 49945 / STATE explore / EPSILON 0.05020584399992392 / ACTION 1 / REWARD 0.1 / Q_MAX  4.068731 / Loss  0.2125302255153656
# fps: 5.899460450880776
# TIMESTEP 49946 / STATE explore / EPSILON 0.05020484499992392 / ACTION 1 / REWARD 0.1 / Q_MAX  1.6037662 / Loss  0.2662997841835022
# fps: 3.6941559236525983
# TIMESTEP 49947 / STATE explore / EPSILON 0.05020384599992392 / ACTION 1 / REWARD 0.1 / Q_MAX  6.7014546 / Loss  0.09923525154590607
# fps: 4.65103054886832
# TIMESTEP 49948 / STATE explore / EPSILON 0.05020284699992392 / ACTION 1 / REWARD 0.1 / Q_MAX  6.1120505 / Loss  0.2640684247016907
# fps: 2.5968558898973284
# TIMESTEP 49949 / STATE explore / EPSILON 0.050201847999923915 / ACTION 1 / REWARD 0.1 / Q_MAX  3.990615 / Loss  0.38035374879837036
# fps: 3.8718665678307578
# TIMESTEP 49950 / STATE explore / EPSILON 0.050200848999923914 / ACTION 1 / REWARD 0.1 / Q_MAX  0.33306426 / Loss  0.11119113862514496
# fps: 2.894106428328447
# TIMESTEP 49951 / STATE explore / EPSILON 0.05019984999992391 / ACTION 1 / REWARD -1 / Q_MAX  1.8911488 / Loss  0.43087100982666016
# fps: 3.8301767561466504
# TIMESTEP 49952 / STATE explore / EPSILON 0.05019885099992391 / ACTION 1 / REWARD -1 / Q_MAX  7.8228636 / Loss  0.10253161936998367
# ----------Random Action----------
# fps: 4.667458244633202
# TIMESTEP 49953 / STATE explore / EPSILON 0.05019785199992391 / ACTION 0 / REWARD 0.1 / Q_MAX  7.3532767 / Loss  0.29042842984199524
# fps: 3.8519821943686523
# TIMESTEP 49954 / STATE explore / EPSILON 0.05019685299992391 / ACTION 0 / REWARD 0.1 / Q_MAX  7.1918573 / Loss  0.08355562388896942
# fps: 4.148217305733303
# TIMESTEP 49955 / STATE explore / EPSILON 0.050195853999923906 / ACTION 1 / REWARD 0.1 / Q_MAX  6.410175 / Loss  0.08487223088741302
# fps: 3.3812488915402352
# TIMESTEP 49956 / STATE explore / EPSILON 0.050194854999923905 / ACTION 1 / REWARD 0.1 / Q_MAX  3.6814907 / Loss  0.2916520833969116
# fps: 4.550296442151741
# TIMESTEP 49957 / STATE explore / EPSILON 0.0501938559999239 / ACTION 1 / REWARD 0.1 / Q_MAX  6.7750435 / Loss  0.13678735494613647
# fps: 5.649495367183849
# TIMESTEP 49958 / STATE explore / EPSILON 0.0501928569999239 / ACTION 1 / REWARD 0.1 / Q_MAX  2.5294542 / Loss  0.19642135500907898
# ----------Random Action----------
# fps: 5.778217396215914
# TIMESTEP 49959 / STATE explore / EPSILON 0.0501918579999239 / ACTION 0 / REWARD 0.1 / Q_MAX  2.2380383 / Loss  0.22598695755004883
# ----------Random Action----------
# fps: 4.7644083372238715
# TIMESTEP 49960 / STATE explore / EPSILON 0.0501908589999239 / ACTION 0 / REWARD 0.1 / Q_MAX  1.5999976 / Loss  0.21453478932380676
# fps: 4.368984748202638
# TIMESTEP 49961 / STATE explore / EPSILON 0.0501898599999239 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5564979 / Loss  0.227297842502594
# fps: 4.419336620727441
# TIMESTEP 49962 / STATE explore / EPSILON 0.050188860999923895 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.57901114 / Loss  0.37312281131744385
# fps: 3.5914872337619856
# TIMESTEP 49963 / STATE explore / EPSILON 0.050187861999923894 / ACTION 1 / REWARD 0.1 / Q_MAX  5.067994 / Loss  0.23814308643341064
# fps: 6.684725060005164
# TIMESTEP 49964 / STATE explore / EPSILON 0.05018686299992389 / ACTION 1 / REWARD 0.1 / Q_MAX  4.7161484 / Loss  0.3600737452507019
# fps: 5.460409045343887
# TIMESTEP 49965 / STATE explore / EPSILON 0.05018586399992389 / ACTION 1 / REWARD 0.1 / Q_MAX  4.8134055 / Loss  0.2522645592689514
# fps: 2.748742872234663
# TIMESTEP 49966 / STATE explore / EPSILON 0.05018486499992389 / ACTION 1 / REWARD 0.1 / Q_MAX  4.5636034 / Loss  0.3613079786300659
# fps: 5.699649946731024
# TIMESTEP 49967 / STATE explore / EPSILON 0.05018386599992389 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5457197 / Loss  0.3177945017814636
# fps: 5.35582087265205
# TIMESTEP 49968 / STATE explore / EPSILON 0.050182866999923886 / ACTION 1 / REWARD 0.1 / Q_MAX  1.2174911 / Loss  0.11359965801239014
# fps: 3.032538500469959
# TIMESTEP 49969 / STATE explore / EPSILON 0.050181867999923885 / ACTION 1 / REWARD 0.1 / Q_MAX  8.372432 / Loss  0.07589296996593475
# fps: 3.1350632984245843
# TIMESTEP 49970 / STATE explore / EPSILON 0.05018086899992388 / ACTION 1 / REWARD 0.1 / Q_MAX  7.2586503 / Loss  0.1253821700811386
# fps: 4.236469581747129
# TIMESTEP 49971 / STATE explore / EPSILON 0.05017986999992388 / ACTION 1 / REWARD 0.1 / Q_MAX  5.9353395 / Loss  0.19706296920776367
# fps: 5.816221283275485
# TIMESTEP 49972 / STATE explore / EPSILON 0.05017887099992388 / ACTION 1 / REWARD 0.1 / Q_MAX  -0.3838638 / Loss  0.13680215179920197
# fps: 4.233032009858192
# TIMESTEP 49973 / STATE explore / EPSILON 0.05017787199992388 / ACTION 1 / REWARD 0.1 / Q_MAX  4.814727 / Loss  0.20883022248744965
# fps: 5.017194067843241
# TIMESTEP 49974 / STATE explore / EPSILON 0.05017687299992388 / ACTION 1 / REWARD 0.1 / Q_MAX  0.8820617 / Loss  0.4100601375102997
# fps: 6.523439286175324
# TIMESTEP 49975 / STATE explore / EPSILON 0.050175873999923876 / ACTION 1 / REWARD 0.1 / Q_MAX  1.5283843 / Loss  0.42285051941871643
# fps: 2.983755574573188
# TIMESTEP 49976 / STATE explore / EPSILON 0.050174874999923874 / ACTION 1 / REWARD -1 / Q_MAX  -0.19752222 / Loss  0.14081379771232605
# fps: 5.848010161470904
# TIMESTEP 49977 / STATE explore / EPSILON 0.05017387599992387 / ACTION 1 / REWARD -1 / Q_MAX  6.7548013 / Loss  0.09791745990514755
# fps: 6.875885652833925
# TIMESTEP 49978 / STATE explore / EPSILON 0.05017287699992387 / ACTION 1 / REWARD -1 / Q_MAX  8.197905 / Loss  0.11010891944169998
# fps: 5.688341102134533
# TIMESTEP 49979 / STATE explore / EPSILON 0.05017187799992387 / ACTION 1 / REWARD 0.1 / Q_MAX  3.7377894 / Loss  0.4491732120513916
# fps: 2.811050636126688
# TIMESTEP 49980 / STATE explore / EPSILON 0.05017087899992387 / ACTION 1 / REWARD 0.1 / Q_MAX  2.5655315 / Loss  0.20300006866455078
# fps: 4.335435429537742
# TIMESTEP 49981 / STATE explore / EPSILON 0.050169879999923866 / ACTION 1 / REWARD 0.1 / Q_MAX  3.4896524 / Loss  0.31270599365234375
# fps: 3.7489041908888745
# TIMESTEP 49982 / STATE explore / EPSILON 0.050168880999923865 / ACTION 1 / REWARD 0.1 / Q_MAX  7.9412394 / Loss  0.17079320549964905
# fps: 2.569996697358561
# TIMESTEP 49983 / STATE explore / EPSILON 0.05016788199992386 / ACTION 1 / REWARD 0.1 / Q_MAX  5.6219726 / Loss  0.14756524562835693
# fps: 4.423629370179474
# TIMESTEP 49984 / STATE explore / EPSILON 0.05016688299992386 / ACTION 1 / REWARD 0.1 / Q_MAX  0.68060845 / Loss  0.31034186482429504
# fps: 2.8508380271781943
# TIMESTEP 49985 / STATE explore / EPSILON 0.05016588399992386 / ACTION 1 / REWARD 0.1 / Q_MAX  7.2516675 / Loss  0.2846490442752838
# fps: 4.254103939071529
# TIMESTEP 49986 / STATE explore / EPSILON 0.05016488499992386 / ACTION 1 / REWARD 0.1 / Q_MAX  6.1611776 / Loss  0.1543487012386322
# fps: 4.2430137984056975
# TIMESTEP 49987 / STATE explore / EPSILON 0.05016388599992386 / ACTION 1 / REWARD 0.1 / Q_MAX  6.147208 / Loss  0.42325735092163086
# fps: 3.900571465770177
# TIMESTEP 49988 / STATE explore / EPSILON 0.050162886999923856 / ACTION 1 / REWARD 0.1 / Q_MAX  0.74026275 / Loss  0.24988877773284912
# fps: 6.333424437031993
# TIMESTEP 49989 / STATE explore / EPSILON 0.050161887999923854 / ACTION 1 / REWARD 0.1 / Q_MAX  3.982457 / Loss  0.3240099549293518
# fps: 7.803124000029767
# TIMESTEP 49990 / STATE explore / EPSILON 0.05016088899992385 / ACTION 1 / REWARD 0.1 / Q_MAX  6.8516874 / Loss  0.6484272480010986
# fps: 7.284446212067268
# TIMESTEP 49991 / STATE explore / EPSILON 0.05015988999992385 / ACTION 1 / REWARD 0.1 / Q_MAX  1.3785161 / Loss  0.19403627514839172
# fps: 5.893285036440456
# TIMESTEP 49992 / STATE explore / EPSILON 0.05015889099992385 / ACTION 1 / REWARD 0.1 / Q_MAX  1.4563646 / Loss  0.07610350102186203
# fps: 5.118506685671539
# TIMESTEP 49993 / STATE explore / EPSILON 0.05015789199992385 / ACTION 1 / REWARD 0.1 / Q_MAX  3.1751149 / Loss  0.27390095591545105
# fps: 3.231702600122355
# TIMESTEP 49994 / STATE explore / EPSILON 0.05015689299992385 / ACTION 1 / REWARD 0.1 / Q_MAX  4.2622757 / Loss  0.086802177131176
# fps: 4.415456557119907
# TIMESTEP 49995 / STATE explore / EPSILON 0.050155893999923845 / ACTION 1 / REWARD 0.1 / Q_MAX  7.1350636 / Loss  0.14259368181228638
# fps: 2.810732278726162
# TIMESTEP 49996 / STATE explore / EPSILON 0.050154894999923844 / ACTION 1 / REWARD 0.1 / Q_MAX  1.9528763 / Loss  0.09460928291082382
# fps: 4.350373654868404
# TIMESTEP 49997 / STATE explore / EPSILON 0.05015389599992384 / ACTION 1 / REWARD 0.1 / Q_MAX  5.7730813 / Loss  0.22043052315711975
# fps: 6.303328318888627
# TIMESTEP 49998 / STATE explore / EPSILON 0.05015289699992384 / ACTION 1 / REWARD 0.1 / Q_MAX  3.7524126 / Loss  0.39376193284988403
# fps: 6.4855022266204845
# TIMESTEP 49999 / STATE explore / EPSILON 0.05015189799992384 / ACTION 1 / REWARD 0.1 / Q_MAX  6.4735346 / Loss  0.24793823063373566
# fps: 6.258791367851185
# Now we save model
